# %%
import googlemaps
from datetime import datetime

gmaps = googlemaps.Client(key='AIzaSyDpfaFWrGicg_6rF6kVrNn2RdrbVjTZ-20')

geocode_result = gmaps.places(query="ATM", region=".id")
geocode_result_str = str(geocode_result).replace('\'', '\"').replace('True', 'true').replace('False', 'false')

# %%
import pandas as pd
import json

results = json.loads(geocode_result_str)['results']

# %%
df = pd.DataFrame(results)
geo = df['geometry'].tolist()
geo = [(g['location']['lat'], g['location']['lng']) for g in geo]
df['geometry'] = geo
df.head()
# Out:
#   business_status                                  formatted_address  \
# 0     OPERATIONAL              Hill 50, 5664 HM Geldrop, Netherlands
# 1     OPERATIONAL  415 W 11th St, Coffeyville, KS 67337, United S...
# 2     OPERATIONAL  1414 W 11th St, Coffeyville, KS 67337, United ...
# 3     OPERATIONAL  601 W 8th St, Coffeyville, KS 67337, United St...
# 4     OPERATIONAL  901 Northeast St, Coffeyville, KS 67337, Unite...
#
#                            geometry  \
# 0            (37.09024, -95.712891)
# 1  (37.03260909999999, -95.6217695)
# 2         (37.0335826, -95.6393307)
# 3         (37.0358374, -95.6244237)
# 4         (37.0358907, -95.6000002)
#
#                                                 icon name  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...  ING
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...  ATM
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...  ATM
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...  ATM
# ...

# %%
df.to_csv('demo.csv')
